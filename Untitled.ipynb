# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
df = pd.read_csv("housing.csv")

# %%
df
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20640 entries, 0 to 20639
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           20640 non-null  float64
#  1   latitude            20640 non-null  float64
#  2   housing_median_age  20640 non-null  float64
#  3   total_rooms         20640 non-null  float64
#  4   total_bedrooms      20433 non-null  float64
#  5   population          20640 non-null  float64
#  6   households          20640 non-null  float64
#  7   median_income       20640 non-null  float64
#  8   median_house_value  20640 non-null  float64
#  9   ocean_proximity     20640 non-null  object
# dtypes: float64(9), object(1)
# memory usage: 1.6+ MB

# %%
df.dropna(inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 20433 entries, 0 to 20639
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           20433 non-null  float64
#  1   latitude            20433 non-null  float64
#  2   housing_median_age  20433 non-null  float64
#  3   total_rooms         20433 non-null  float64
#  4   total_bedrooms      20433 non-null  float64
#  5   population          20433 non-null  float64
#  6   households          20433 non-null  float64
#  7   median_income       20433 non-null  float64
#  8   median_house_value  20433 non-null  float64
#  9   ocean_proximity     20433 non-null  object
# dtypes: float64(9), object(1)
# memory usage: 1.7+ MB

# %%
from sklearn.model_selection import train_test_split

# %%
x = df.drop(['median_house_value'],axis = 1)
y = df['median_house_value']
x_train ,x_test, y_train, y_test = train_test_split(x,y,test_size=0.2)

# %%
train_data = x_train.join(y_train)
test_data = x_test.join(y_test)

# %%
train_data.hist(figsize=(15, 8))
# Out:
# array([[<Axes: title={'center': 'longitude'}>,
#         <Axes: title={'center': 'latitude'}>,
#         <Axes: title={'center': 'housing_median_age'}>],
#        [<Axes: title={'center': 'total_rooms'}>,
#         <Axes: title={'center': 'total_bedrooms'}>,
#         <Axes: title={'center': 'population'}>],
#        [<Axes: title={'center': 'households'}>,
#         <Axes: title={'center': 'median_income'}>,
#         <Axes: title={'center': 'median_house_value'}>]], dtype=object)

# %%
test_data
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 7133     -118.10     34.01                29.0       2077.0           564.0
# 5486     -118.46     33.98                27.0       2217.0           520.0
# 6261     -117.96     34.04                35.0       1141.0           212.0
# 2649     -124.10     40.50                42.0       2380.0           553.0
# 12770    -121.42     38.63                42.0       1385.0           273.0
# ...          ...       ...                 ...          ...             ...
# 11398    -117.95     33.72                21.0       3107.0           483.0
# 16548    -121.22     37.82                13.0       4452.0           949.0
# 11687    -117.99     33.88                42.0       1461.0           302.0
# 6697     -118.11     34.14                52.0       2401.0           332.0
# 20585    -122.04     38.68                26.0       1113.0           222.0
#
# ...

# %%
train_data = train_data.join(pd.get_dummies(train_data['ocean_proximity']))
test_data = test_data.join(pd.get_dummies(test_data['ocean_proximity']))

train_data
test_data
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 7133     -118.10     34.01                29.0       2077.0           564.0
# 5486     -118.46     33.98                27.0       2217.0           520.0
# 6261     -117.96     34.04                35.0       1141.0           212.0
# 2649     -124.10     40.50                42.0       2380.0           553.0
# 12770    -121.42     38.63                42.0       1385.0           273.0
# ...          ...       ...                 ...          ...             ...
# 11398    -117.95     33.72                21.0       3107.0           483.0
# 16548    -121.22     37.82                13.0       4452.0           949.0
# 11687    -117.99     33.88                42.0       1461.0           302.0
# 6697     -118.11     34.14                52.0       2401.0           332.0
# 20585    -122.04     38.68                26.0       1113.0           222.0
#
# ...

# %%
train_data = train_data.drop(['ocean_proximity'],axis =1)
test_data = test_data.drop(['ocean_proximity'],axis =1)

# %%
train_data.corr()
# Out:
#                     longitude  latitude  housing_median_age  total_rooms  \
# longitude            1.000000 -0.924423           -0.108944     0.040928
# latitude            -0.924423  1.000000            0.010207    -0.031207
# housing_median_age  -0.108944  0.010207            1.000000    -0.359485
# total_rooms          0.040928 -0.031207           -0.359485     1.000000
# total_bedrooms       0.066932 -0.063256           -0.318946     0.929927
# population           0.098832 -0.106664           -0.290949     0.853871
# households           0.053853 -0.067946           -0.300008     0.918990
# median_income       -0.021245 -0.073781           -0.114249     0.197940
# median_house_value  -0.051353 -0.138506            0.110276     0.133262
# <1H OCEAN            0.321422 -0.446529            0.042891    -0.005593
# INLAND              -0.048706  0.345052           -0.239971     0.028024
# ISLAND               0.008162 -0.014448            0.016831    -0.005661
# ...

# %%
plt.figure(figsize=(15, 8))
sns.heatmap(train_data.corr(), annot=True, cmap="coolwarm")
# Out:
# <Axes: >

# %%
plt.figure(figsize=(15,8))
sns.scatterplot(x='latitude',y='longitude', data = train_data, hue='median_house_value',palette='coolwarm')
# Out:
# <Axes: xlabel='latitude', ylabel='longitude'>

# %%
plt.figure(figsize=(15, 8))
sns.heatmap(train_data.corr(), annot=True, cmap="coolwarm")
# Out:
# <Axes: >

# %% [markdown]
# # train model de ML

# %% [markdown]
# * regression linear

# %%
from sklearn.linear_model import LinearRegression
x_train, y_train = train_data.drop(['median_house_value'], axis=1
                                  ), train_data['median_house_value']
rg = LinearRegression()
rg.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
x_test, y_test = test_data.drop(['median_house_value'],axis=1),test_data['median_house_value']

# %%
rg.score(x_test,y_test)
# Out:
# 0.6250174425994159

# %% [markdown]
# * Random Forest

# %%
from sklearn.ensemble import RandomForestRegressor
frst = RandomForestRegressor()
frst.fit(x_train, y_train)

frst.score(x_test, y_test)
# Out:
# 0.8108816876126903

# %%
# vhercher automatiquement les meilleurs hyperparametres 
from sklearn.model_selection import GridSearchCV
from sklearn.preprocessing import StandardScaler
from sklearn.ensemble import RandomForestRegressor

forest = RandomForestRegressor()

scaler = StandardScaler()
x_train_s = scaler.fit_transform(x_train)

param_grid = {
    'n_estimators': [100, 200, 300],
    'min_samples_split': [2, 4],  # CORRIGÉ
    'max_depth': [None, 4, 8]
}

grid_search = GridSearchCV(forest, param_grid, cv=5,
                           scoring='neg_mean_squared_error',
                           return_train_score=True)


grid_search.fit(x_train_s, y_train)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[34], line 22
#      11 param_grid = {
#      12     'n_estimators': [100, 200, 300],
#      13     'min_samples_split': [2, 4],  # CORRIGÉ
#      14     'max_depth': [None, 4, 8]
#      15 }
#      17 grid_search = GridSearchCV(forest, param_grid, cv=5,
#      18                            scoring='neg_mean_squared_error',
#      19                            return_train_score=True)
# ---> 22 grid_search.fit(x_train_s, y_train)
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\base.py:1363, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1356     estimator._validate_params()
#    1358 with config_context(
#    1359     skip_parameter_validation=(
#    1360         prefer_skip_nested_validation or global_skip_validation
#    1361     )
#    1362 ):
# ...

# %%
grid_search.best_estimator
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[35], line 1
# ----> 1 grid_search.best_estimator
#
# AttributeError: 'GridSearchCV' object has no attribute 'best_estimator'

# %%
y_pred = rg.predict(x_test)

# Prédire sur les données de test
y_pred = rg.predict(x_test)

# Afficher quelques résultats pour comparer
for true, pred in zip(y_test[:5], y_pred[:5]):
    print(f"Réel : {true:.2f} | Prédit : {pred:.2f}")


import matplotlib.pyplot as plt

plt.scatter(y_test, y_pred, alpha=0.7)
plt.xlabel("Valeurs réelles")
plt.ylabel("Valeurs prédites")
plt.title("Réel vs Prédit (Régression)")
plt.plot([min(y_test), max(y_test)], [min(y_test), max(y_test)], color='red')  # diagonale parfaite
plt.show()
# Out:
# Réel : 189200.00 | Prédit : 157276.63
# Réel : 500001.00 | Prédit : 252292.58
# Réel : 148300.00 | Prédit : 176489.42
# Réel : 57500.00 | Prédit : 155609.35
# Réel : 78000.00 | Prédit : 113592.43

# %%
from sklearn.ensemble import RandomForestRegressor

forest = RandomForestRegressor()
forest.fit(x_train, y_train)

score = forest.score(x_test, y_test)
print("Score R² sur le jeu de test :", score)
